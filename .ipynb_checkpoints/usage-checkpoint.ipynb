# %% [markdown]
# # [FMA: A Dataset For Music Analysis](https://github.com/mdeff/fma)
#
# Michaël Defferrard, Kirell Benzi, Pierre Vandergheynst, Xavier Bresson, EPFL LTS2.
#
# ## Usage
#
# 1. Go through the [paper] to understand what the data is about.
# 1. Download some datasets from <https://github.com/mdeff/fma>.
# 1. Uncompress the archives, e.g. with `unzip fma_small.zip`.
# 1. Load and play with the data in this notebook.
#
# [paper]: https://arxiv.org/abs/1612.01840

# %%
# %matplotlib inline

import os
from dotenv import load_dotenv

import IPython.display as ipd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl
import sklearn.utils, sklearn.preprocessing, sklearn.decomposition, sklearn.svm
import librosa
import librosa.display

import utils

plt.rcParams['figure.figsize'] = (17, 5)
if "AUDIO_DIR" in os.environ:
    del os.environ["AUDIO_DIR"]

# Force reload the .env file
load_dotenv(override=True)
# Out:
# True

# %%
# Directory where mp3 are stored.
AUDIO_DIR = os.environ.get('AUDIO_DIR')
print(f"AUDIO_DIR: {AUDIO_DIR}")


# Load metadata and features.
tracks = utils.load('data/fma_metadata/tracks.csv')
genres = utils.load('data/fma_metadata/genres.csv')
features = utils.load('data/fma_metadata/features.csv')
echonest = utils.load('data/fma_metadata/echonest.csv')

np.testing.assert_array_equal(features.index, tracks.index)
assert echonest.index.isin(tracks.index).all()

tracks.shape, genres.shape, features.shape, echonest.shape
# Out:
# AUDIO_DIR: ./data/fma_small/
# ((106574, 52), (163, 4), (106574, 518), (13129, 249))

# %% [markdown]
# ## 1 Metadata
#
# The metadata table, a CSV file in the `fma_metadata.zip` archive, is composed of many colums:
# 1. The index is the ID of the song, taken from the website, used as the name of the audio file.
# 2. Per-track, per-album and per-artist metadata from the Free Music Archive website.
# 3. Two columns to indicate the subset (small, medium, large) and the split (training, validation, test).

# %%
ipd.display(tracks['track'].head())
ipd.display(tracks['album'].head())
ipd.display(tracks['artist'].head())
ipd.display(tracks['set'].head())
# Out:
#           bit_rate  comments   composer        date_created date_recorded  \
# track_id
# 2           256000         0        NaN 2008-11-26 01:48:12    2008-11-26
# 3           256000         0        NaN 2008-11-26 01:48:14    2008-11-26
# 5           256000         0        NaN 2008-11-26 01:48:20    2008-11-26
# 10          192000         0  Kurt Vile 2008-11-25 17:49:06    2008-11-26
# 20          256000         0        NaN 2008-11-26 01:48:56    2008-01-01
#
#           duration  favorites genre_top     genres         genres_all  \
# track_id
# 2              168          2   Hip-Hop       [21]               [21]
# 3              237          1   Hip-Hop       [21]               [21]
# 5              206          6   Hip-Hop       [21]               [21]
# 10             161        178       Pop       [10]               [10]
# 20             311          0       NaN  [76, 103]  [17, 10, 76, 103]
#
#          information  interest language_code  \
# track_id
# ...

# %% [markdown]
# ### 1.1 Subsets
#
# The small and medium subsets can be selected with the below code.

# %%
small = tracks[tracks['set', 'subset'] <= 'small']
small.shape
# Out:
# (8000, 52)

# %%
medium = tracks[tracks['set', 'subset'] <= 'medium']
medium.shape
# Out:
# (25000, 52)

# %% [markdown]
# ## 2 Genres
#
# The genre hierarchy is stored in `genres.csv` and distributed in `fma_metadata.zip`.

# %%
print('{} top-level genres'.format(len(genres['top_level'].unique())))
genres.loc[genres['top_level'].unique()].sort_values('#tracks', ascending=False)
# Out:
# 16 top-level genres
#           #tracks  parent                title  top_level
# genre_id
# 38          38154       0         Experimental         38
# 15          34413       0           Electronic         15
# 12          32923       0                 Rock         12
# 1235        14938       0         Instrumental       1235
# 10          13845       0                  Pop         10
# 17          12706       0                 Folk         17
# 21           8389       0              Hip-Hop         21
# 2            5271       0        International          2
# 4            4126       0                 Jazz          4
# 5            4106       0            Classical          5
# 9            1987       0              Country          9
# 20           1876       0               Spoken         20
# 3            1752       0                Blues          3
# 14           1499       0             Soul-RnB         14
# 8             868       0  Old-Time / Historic          8
# ...

# %%
genres.sort_values('#tracks').head(10)
# Out:
#           #tracks  parent                     title  top_level
# genre_id
# 175             0      86                 Bollywood          2
# 178             0       4                    Be-Bop          4
# 377             1      19                 Deep Funk         14
# 173             4      86     N. Indian Traditional          2
# 493             4     651             Western Swing          9
# 374             9      20                    Banter         20
# 808            12      46                     Salsa          2
# 174            17      86  South Indian Traditional          2
# 465            18      20           Musical Theater         20
# 176            23       2                   Pacific          2

# %% [markdown]
# ## 3 Features
#
# 1. Features extracted from the audio for all tracks.
# 2. For some tracks, data colected from the [Echonest](http://the.echonest.com/) API.

# %%
print('{1} features for {0} tracks'.format(*features.shape))
columns = ['mfcc', 'chroma_cens', 'tonnetz', 'spectral_contrast']
columns.append(['spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff'])
columns.append(['rmse', 'zcr'])
for column in columns:
    ipd.display(features[column].head().style.format('{:.2f}'))
# Out:
# 518 features for 106574 tracks
# <style type="text/css">
# </style>
# <table id="T_344b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >statistics</th>
#       <th id="T_344b0_level0_col0" class="col_heading level0 col0" colspan="20">kurtosis</th>
#       <th id="T_344b0_level0_col20" class="col_heading level0 col20" colspan="20">max</th>
#       <th id="T_344b0_level0_col40" class="col_heading level0 col40" colspan="20">mean</th>
#       <th id="T_344b0_level0_col60" class="col_heading level0 col60" colspan="20">median</th>
#       <th id="T_344b0_level0_col80" class="col_heading level0 col80" colspan="20">min</th>
#       <th id="T_344b0_level0_col100" class="col_heading level0 col100" colspan="20">skew</th>
#       <th id="T_344b0_level0_col120" class="col_heading level0 col120" colspan="20">std</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >number</th>
#       <th id="T_344b0_level1_col0" class="col_heading level1 col0" >01</th>
# ...

# %% [markdown]
# ### 3.1 Echonest features

# %%
print('{1} features for {0} tracks'.format(*echonest.shape))
ipd.display(echonest['echonest', 'metadata'].head())
ipd.display(echonest['echonest', 'audio_features'].head())
ipd.display(echonest['echonest', 'social_features'].head())
ipd.display(echonest['echonest', 'ranks'].head())
# Out:
# 249 features for 13129 tracks
#           album_date         album_name  artist_latitude  \
# track_id
# 2                NaN                NaN          32.6783
# 3                NaN                NaN          32.6783
# 5                NaN                NaN          32.6783
# 10        2008-03-11  Constant Hitmaker          39.9523
# 134              NaN                NaN          32.6783
#
#                artist_location  artist_longitude artist_name  \
# track_id
# 2                  Georgia, US          -83.2230        AWOL
# 3                  Georgia, US          -83.2230        AWOL
# 5                  Georgia, US          -83.2230        AWOL
# 10        Philadelphia, PA, US          -75.1624   Kurt Vile
# 134                Georgia, US          -83.2230        AWOL
#
#                        release
# track_id
# 2         AWOL - A Way Of Life
# 3         AWOL - A Way Of Life
# 5         AWOL - A Way Of Life
# 10           Constant Hitmaker
# ...

# %%
ipd.display(echonest['echonest', 'temporal_features'].head())
x = echonest.loc[2, ('echonest', 'temporal_features')]
plt.plot(x);
# Out:
#                000       001       002       003       004       005  \
# track_id
# 2         0.877233  0.588911  0.354243  0.295090  0.298413  0.309430
# 3         0.534429  0.537414  0.443299  0.390879  0.344573  0.366448
# 5         0.548093  0.720192  0.389257  0.344934  0.361300  0.402543
# 10        0.311404  0.711402  0.321914  0.500601  0.250963  0.321316
# 134       0.610849  0.569169  0.428494  0.345796  0.376920  0.460590
#
#                006       007       008       009  ...       214        215  \
# track_id                                          ...
# 2         0.304496  0.334579  0.249495  0.259656  ... -1.992303   6.805694
# 3         0.419455  0.747766  0.460901  0.392379  ... -1.582331   8.889308
# 5         0.434044  0.388137  0.512487  0.525755  ... -2.288358  11.527109
# 10        0.734250  0.325188  0.373012  0.235840  ... -3.662988  21.508228
# 134       0.401371  0.449900  0.428946  0.446736  ... -1.452696   2.356398
#
# ...

# %% [markdown]
# ### 3.2 Features like MFCCs are discriminant

# %%
small = tracks['set', 'subset'] <= 'small'
genre1 = tracks['track', 'genre_top'] == 'Instrumental'
genre2 = tracks['track', 'genre_top'] == 'Hip-Hop'

X = features.loc[small & (genre1 | genre2), 'mfcc']
X = skl.decomposition.PCA(n_components=2).fit_transform(X)

y = tracks.loc[small & (genre1 | genre2), ('track', 'genre_top')]
y = skl.preprocessing.LabelEncoder().fit_transform(y)

plt.scatter(X[:,0], X[:,1], c=y, cmap='RdBu', alpha=0.5)
X.shape, y.shape
# Out:
# ((2000, 2), (2000,))

# %% [markdown]
# ## 4 Audio
#
# You can load the waveform and listen to audio in the notebook itself.

# %%
filename = utils.get_audio_path(AUDIO_DIR, 2)
print('File: {}'.format(filename))

x, sr = librosa.load(filename, sr=None, mono=True)
print('Duration: {:.2f}s, {} samples'.format(x.shape[-1] / sr, x.size))

start, end = 7, 17
ipd.Audio(data=x[start*sr:end*sr], rate=sr)
# Out:
# File: ./data/fma_small/000/000002.mp3
# Duration: 29.98s, 1321967 samples
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# And use [librosa](https://github.com/librosa/librosa) to compute spectrograms and audio features.

# %%
librosa.display.waveshow(x, sr=sr, alpha=0.5)

plt.vlines([start, end], -1, 1)

start = len(x) // 2
plt.figure()
plt.plot(x[start:start+2000])
plt.ylim((-1, 1));

# %%
stft = np.abs(librosa.stft(x, n_fft=2048, hop_length=512))
mel = librosa.feature.melspectrogram(sr=sr, S=stft**2)
log_mel = librosa.power_to_db(mel)


librosa.display.specshow(log_mel, sr=sr, hop_length=512, x_axis='time', y_axis='mel');

# %%
mfcc = librosa.feature.mfcc(S=librosa.power_to_db(mel), n_mfcc=20)
mfcc = skl.preprocessing.StandardScaler().fit_transform(mfcc)
librosa.display.specshow(mfcc, sr=sr, x_axis='time');

# %% [markdown]
# ## 5 Genre classification

# %% [markdown]
# ### 5.1 From features

# %%
small = tracks['set', 'subset'] <= 'small'

train = tracks['set', 'split'] == 'training'
val = tracks['set', 'split'] == 'validation'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[small & train, ('track', 'genre_top')]
y_test = tracks.loc[small & test, ('track', 'genre_top')]
X_train = features.loc[small & train, 'mfcc']
X_test = features.loc[small & test, 'mfcc']

print('{} training examples, {} testing examples'.format(y_train.size, y_test.size))
print('{} features, {} classes'.format(X_train.shape[1], np.unique(y_train).size))
# Out:
# 6400 training examples, 800 testing examples
# 140 features, 8 classes

# %%
# Be sure training samples are shuffled.
X_train, y_train = skl.utils.shuffle(X_train, y_train, random_state=42)

# Standardize features by removing the mean and scaling to unit variance.
scaler = skl.preprocessing.StandardScaler(copy=False)
scaler.fit_transform(X_train)
scaler.transform(X_test)

# Support vector classification.
clf = skl.svm.SVC()
clf.fit(X_train, y_train)
score = clf.score(X_test, y_test)
print('Accuracy: {:.2%}'.format(score))
# Out:
# Accuracy: 46.38%

# %% [markdown]
# # 6.1.Data Load & Preprocess

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Load dataset using utils.load()
import utils

tracks = utils.load('data/fma_metadata/tracks.csv')
genres = utils.load('data/fma_metadata/genres.csv')
features = utils.load('data/fma_metadata/features.csv')
echonest = utils.load('data/fma_metadata/echonest.csv')

# Check the shapes of the loaded datasets
print("Tracks:", tracks.shape)
print("Genres:", genres.shape)
print("Features:", features.shape)
print("Echonest:", echonest.shape)

# Extracting MFCC features for training
small = tracks['set', 'subset'] <= 'small'
train = tracks['set', 'split'] == 'training'
test = tracks['set', 'split'] == 'test'

y_train = tracks.loc[small & train, ('track', 'genre_top')]
y_test = tracks.loc[small & test, ('track', 'genre_top')]
X_train = features.loc[small & train, 'mfcc']
X_test = features.loc[small & test, 'mfcc']

print(f"{y_train.size} training examples, {y_test.size} testing examples")
print(f"{X_train.shape[1]} features, {np.unique(y_train).size} classes")

# ✅ Fix 1: Scale Features to Improve Convergence
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# ✅ Fix 2: Check for Missing Values and Handle Them
print("Missing values in X_train:", np.isnan(X_train).sum())
print("Missing values in X_test:", np.isnan(X_test).sum())

X_train = np.nan_to_num(X_train)
X_test = np.nan_to_num(X_test)

# ✅ Fix 3: Reduce Feature Dimensions Using PCA (If Needed)
if X_train.shape[1] > 200:  # Apply PCA if too many features
    print("Applying PCA to reduce features...")
    pca = PCA(n_components=50)
    X_train = pca.fit_transform(X_train)
    X_test = pca.transform(X_test)

# ✅ Fix 4: Train Logistic Regression with Improved Settings
lr_model = LogisticRegression(max_iter=2000, solver='saga', random_state=42)
lr_model.fit(X_train, y_train)

# Predict on test set
y_pred_lr = lr_model.predict(X_test)

# Evaluate performance
lr_accuracy = accuracy_score(y_test, y_pred_lr)
lr_f1 = f1_score(y_test, y_pred_lr, average='macro')
lr_confusion = confusion_matrix(y_test, y_pred_lr)

print("Logistic Regression Accuracy:", lr_accuracy)
print("Logistic Regression F1-score:", lr_f1)
print("Logistic Regression Confusion Matrix:\n", lr_confusion)
# Out:
# Tracks: (106574, 52)
# Genres: (163, 4)
# Features: (106574, 518)
# Echonest: (13129, 249)
# 6400 training examples, 800 testing examples
# 140 features, 8 classes
# Missing values in X_train: 0
# Missing values in X_test: 0
# Logistic Regression Accuracy: 0.4125
# Logistic Regression F1-score: 0.40586931052829517
# Logistic Regression Confusion Matrix:
#  [[52  3  4 14  2 10 12  3]
#  [ 9 24 11  4 19 12 13  8]
#  [ 3 22 14  0  6 24 24  7]
#  [13  3  2 69  2  8  1  2]
#  [ 7  8 25  3 41  0  7  9]
#  [ 9  5 20 12  4 38  9  3]
#  [19  3  9 13  4 10 29 13]
#  [ 1 10  5  2  5  4 10 63]]

# %% [markdown]
# # k-Nearest Neighbors (kNN) with Optimized Learning

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

# Encode genre labels as numerical values
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Initialize kNN model
knn_model = KNeighborsClassifier()

# Define hyperparameter search space
param_grid = {'n_neighbors': [3, 5, 7, 9, 11],  # Different k values
              'weights': ['uniform', 'distance'],  # Weighting strategies
              'metric': ['euclidean', 'manhattan']}  # Distance metrics

# Perform Grid Search to optimize kNN
grid_search = GridSearchCV(knn_model, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train_encoded)  # Use encoded labels

# Get the best kNN model
best_knn = grid_search.best_estimator_

# Predict on test set
y_pred_knn = best_knn.predict(X_test)

# Decode predicted values back to original genre labels (optional)
y_pred_knn_labels = label_encoder.inverse_transform(y_pred_knn)

# Evaluate performance
knn_accuracy = accuracy_score(y_test_encoded, y_pred_knn)
knn_f1 = f1_score(y_test_encoded, y_pred_knn, average='macro')
knn_confusion = confusion_matrix(y_test_encoded, y_pred_knn)

print("✅ Best kNN Parameters:", grid_search.best_params_)
print("kNN Accuracy:", knn_accuracy)
print("kNN F1-score:", knn_f1)
print("kNN Confusion Matrix:\n", knn_confusion)
# Out:
# ✅ Best kNN Parameters: {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
# kNN Accuracy: 0.36125
# kNN F1-score: 0.3429272524971797
# kNN Confusion Matrix:
#  [[36  2  2 32  4 14  7  3]
#  [11  7 12  7 28  8 14 13]
#  [ 0  3 21  0 13 37 19  7]
#  [13  1  2 61  5  8  6  4]
#  [ 4  4 29  1 50  7  3  2]
#  [ 2  0 22 16  0 57  1  2]
#  [14  1 16 22  2 26 12  7]
#  [ 3  2  5  2  8  7 28 45]]

# %% [markdown]
# # step1: Load Data

# %%
import numpy as np
import pandas as pd
import utils  # Using your utils.py
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import GridSearchCV

# 📌 Load data using your utils.py
print("\n📂 Loading Data...")
tracks = utils.load('data/fma_metadata/tracks.csv')
features = utils.load('data/fma_metadata/features.csv')
genres = utils.load('data/fma_metadata/genres.csv')

# ✅ Map genre_id to genre names
genre_mapping = genres['title'].to_dict()
tracks[('track', 'genre_top')] = tracks[('track', 'genre_top')].map(genre_mapping)

# ❗ Check for unmapped genres
if tracks[('track', 'genre_top')].isna().sum() > 0:
    print("\n⚠️ Warning: Some genres were not mapped correctly!")

# 📊 Print dataset shapes
print(f"✅ Tracks: {tracks.shape}, Features: {features.shape}, Genres: {genres.shape}")
# Out:
# 📂 Loading Data...
#
# ⚠️ Warning: Some genres were not mapped correctly!
# ✅ Tracks: (106574, 52), Features: (106574, 518), Genres: (163, 4)

# %% [markdown]
# # Step 2: Select Features

# %%
# 🎛 Selecting Relevant Features (Matching MultiIndex Structure)
selected_features = [
    ('chroma_cens', 'mean', '01'), ('chroma_cens', 'std', '01'),  # Chroma (12-dim)
    ('tonnetz', 'mean', '01'), ('tonnetz', 'std', '01'),          # Tonnetz (6-dim)
    ('mfcc', 'mean', '01'), ('mfcc', 'std', '01'),                # MFCC (13-dim)
    ('spectral_centroid', 'mean', '01'), ('spectral_centroid', 'std', '01'),
    ('spectral_bandwidth', 'mean', '01'), ('spectral_bandwidth', 'std', '01'),
    ('spectral_contrast', 'mean', '01'), ('spectral_contrast', 'std', '01'),  # Spectral Contrast (6-dim)
    ('spectral_rolloff', 'mean', '01'), ('spectral_rolloff', 'std', '01'),
    ('rmse', 'mean', '01'), ('rmse', 'std', '01'),  # RMS Energy
    ('zcr', 'mean', '01'), ('zcr', 'std', '01')     # Zero-Crossing Rate
]

# Ensure features exist in DataFrame
existing_features = [col for col in selected_features if col in features.columns]

# Extract X (features) and y (labels)
X = features[existing_features].values
y = tracks[('track', 'genre_top')].values  # Genre names

# ✅ Print shape
print(f"✅ Selected Features Shape: {X.shape}, Labels: {y.shape}")
# Out:
# ✅ Selected Features Shape: (106574, 18), Labels: (106574,)

# %% [markdown]
# # Step 3: Preprocess Data & Split

# %%
from sklearn.preprocessing import LabelEncoder

# 🎯 Encode genre labels into numbers
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# 📌 Train-test split (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# 🔬 Standardize Features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(f"✅ Data Ready: {X_train.shape} training samples, {X_test.shape} testing samples")
# Out:
# ✅ Data Ready: (85259, 18) training samples, (21315, 18) testing samples

# %% [markdown]
# # Train Logistic Regression

# %%
print("Unique classes in y_train:", np.unique(y_train))
# Out:
# Unique classes in y_train: [0]
